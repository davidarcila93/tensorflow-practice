# %% [markdown]
# # Fashion MNIST

# %%
import tensorflow as tf
from tensorflow import keras
print(tf.__version__)
# Out:
# 2.0.0

# %%
fashion_mnist = keras.datasets.fashion_mnist

# %%
(training_images, training_labels),(test_images, test_labels) = fashion_mnist.load_data()

# %%
import matplotlib.pyplot as plt
plt.imshow(training_images[0])

# %%
training_images = training_images / 255.
test_images = test_images / 255.

# %%
model = keras.models.Sequential([keras.layers.Flatten(),
                                keras.layers.Dense(512, activation=tf.nn.relu),
                                keras.layers.Dense(10, activation=tf.nn.softmax)])

# %%
model.compile(optimizer = tf.optimizers.Adam(),
             loss = 'sparse_categorical_crossentropy',
             metrics = ['accuracy'])
model.fit(training_images, training_labels, epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.4736 - accuracy: 0.8299
# Epoch 2/5
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.3581 - accuracy: 0.8673
# Epoch 3/5
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.3250 - accuracy: 0.8806
# Epoch 4/5
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.2991 - accuracy: 0.8895
# Epoch 5/5
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.2801 - accuracy: 0.8955

# %%
model.evaluate(test_images, test_labels)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
