# %% [markdown]
# # Fashion MNIST

# %%
import tensorflow as tf
from tensorflow import keras
print(tf.__version__)
# Out:
# 2.0.0

# %%
fashion_mnist = keras.datasets.fashion_mnist

# %%
(training_images, training_labels),(test_images, test_labels) = fashion_mnist.load_data()

# %%
import matplotlib.pyplot as plt
plt.imshow(training_images[0])

# %%
training_images = training_images / 255.
test_images = test_images / 255.

# %%
model = keras.models.Sequential([keras.layers.Flatten(),
                                keras.layers.Dense(512, activation=tf.nn.relu),
                                keras.layers.Dense(10, activation=tf.nn.softmax)])

# %%
model.compile(optimizer = tf.optimizers.Adam(),
             loss = 'sparse_categorical_crossentropy',
             metrics = ['accuracy'])
model.fit(training_images, training_labels, epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.4777 - accuracy: 0.8293
# Epoch 2/5
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.3592 - accuracy: 0.8677
# Epoch 3/5
# 60000/60000 [==============================] - 4s 67us/sample - loss: 0.3247 - accuracy: 0.8814
# Epoch 4/5
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.2997 - accuracy: 0.8887
# Epoch 5/5
# 60000/60000 [==============================] - 4s 67us/sample - loss: 0.2827 - accuracy: 0.8954

# %%
model.evaluate(test_images, test_labels)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.33345402970314025, 0.8812]
